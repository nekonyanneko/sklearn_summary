# %% [markdown]
# 教師なしデータでクラスター数が不明の場合、サンプル数1万以下であればMeanShiftを利用する

# %%
# ライブラリのインポート--------------------------------
import numpy as np #numpyという行列などを扱うライブラリを利用
import pandas as pd #pandasというデータ分析ライブラリを利用
import matplotlib.pyplot as plt #プロット用のライブラリを利用
from sklearn import cluster, preprocessing, mixture #機械学習用のライブラリを利用

# %%
# Wineのデータセットを読み込む--------------------------------
df_wine_all=pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/wine/wine.data', header=None)
#品種(0列、1～3)と色（10列）とプロリンの量(13列)を使用する
df_wine=df_wine_all[[0,10,13]]
df_wine.columns = [u'class', u'color', u'proline']
pd.DataFrame(df_wine)  #この行を実行するとデータが見れる
# Out:
#      class      color  proline
# 0        1   5.640000     1065
# 1        1   4.380000     1050
# 2        1   5.680000     1185
# 3        1   7.800000     1480
# 4        1   4.320000      735
# 5        1   6.750000     1450
# 6        1   5.250000     1290
# 7        1   5.050000     1295
# 8        1   5.200000     1045
# 9        1   7.220000     1045
# 10       1   5.750000     1510
# 11       1   5.000000     1280
# 12       1   5.600000     1320
# 13       1   5.400000     1150
# 14       1   7.500000     1547
# 15       1   7.300000     1310
# 16       1   6.200000     1280
# 17       1   6.600000     1130
# 18       1   8.700000     1680
# 19       1   5.100000      845
# 20       1   5.650000      780
# 21       1   4.500000      770
# 22       1   3.800000     1035
# 23       1   3.930000     1015
# 24       1   3.520000      845
# 25       1   3.580000      830
# 26       1   4.800000     1195
# 27       1   3.950000     1285
# 28       1   4.500000      915
# ...

# %%
# データの整形-------------------------------------------------------
X=df_wine[["color","proline"]]
sc=preprocessing.StandardScaler()
sc.fit(X)
X_norm=sc.transform(X)

# %%
# プロットしてみる------------------------------------------
# %matplotlib inline
 
x=X_norm[:,0]
y=X_norm[:,1]
z=df_wine["class"]
plt.figure(figsize=(10,10))
plt.subplot(3, 1, 1)
plt.scatter(x,y, c=z)
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %% [markdown]
# MeanShiftは、おおざっぱにはKMeansをクラスター数を仮定せずに行う手法で、規定の距離より近くなったクラスターは合体させて1つにしてしまう。
#
# ここでseedsは最初のクラスターを決めており、最初は各データを中心とするデータ数分のクラスターを用意している。
#
# また規定の距離が非常に重要になり、デフォルトで計算されるが、自分で設定することもできる。

# %%
# MeanShiftを実施---------------------------------
ms = cluster.MeanShift(seeds=X_norm)
ms.fit(X_norm)
labels = ms.labels_
cluster_centers = ms.cluster_centers_
print(cluster_centers)
# Out:
# [[-0.6207637  -0.59667224]
#  [ 1.49736922 -0.30032022]]

# %%
# 結果をプロット-----------------------------------------------
plt.figure(figsize=(10,10))
plt.subplot(3, 1, 1)
plt.scatter(x,y, c=labels)
plt.plot(cluster_centers[0,0], cluster_centers[0,1], marker='*',c='red', markersize=14)
plt.plot(cluster_centers[1,0], cluster_centers[1,1], marker='*',c='red', markersize=14)
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %% [markdown]
# ### MeanShiftとは
#  - [MeanShift:sklearn](http://scikit-learn.org/stable/modules/clustering.html)
#  - [MeanShift:sklearn](http://scikit-learn.org/stable/modules/generated/sklearn.cluster.MeanShift.html)

# %% [markdown]
# MeanShift・Clusteringは教師なし学習の一種で、データを自動的にクラスターに分ける。
#
# その際にいくつのクラスターが存在するのかを指定せずにクラスタリングするが、KMeansをベースとしつつ、近いクラスターはまとめていく単純さから、結果が思うように行かない場合が多いため、VBGMMの方が好ましい。
